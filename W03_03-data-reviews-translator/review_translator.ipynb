# %% [markdown]
# # (Opsiyonal) Olist reviews' - Translations...
#
# * 🇧🇷 Brezilya Portekizcesi bilmiyorsanız, hadi `order_reviews` metinlerini 🇬🇧 İngilizce’ye çevirelim!
#
# * Bunun için `pip install googletrans==4.0.2` yüklemeniz gerekecek.

# %% [markdown]
# ☢️ Bu API ile herhangi bir sorun yaşarsanız, bunu düzeltmek için zaman harcamayın, bu package oldukça dengesiz… Aklınızda bulunsun:
# - bu optional bir challenge
# - Brezilya Portekizcesi ile yazılmış review’ların anlamını görmek için bazı yorumları Google Translate’e kopyalayıp yapıştırarak yine de eski yöntemle yapabilirsiniz.

# %% [markdown]
# ## Review Translator

# %% [markdown]
# 👉 `reviews` dataset’ini load edin ve 1-yıldız rating’e sahip review’lardan bir örnek (sample) seçin.

# %%
# Verileri yükle
from olist.data import Olist
data = Olist().get_data()

# %% [markdown]
# 👀 20 adet düşük puan alan yorumdan oluşan bir örneklem seçin (rastgele) ve bunu bir listeye dönüştürün.

# %%
print(data.keys())
reviews_df = data['order_reviews']
bad_reviews = reviews_df[reviews_df['review_score'] == 1]
bad_reviews_list = bad_reviews['review_comment_message'].dropna().sample(20).tolist()
# Out:
# dict_keys(['sellers', 'geolocation', 'orders', 'order_items', 'product_category_name_translation', 'customers', 'order_payments', 'products', 'order_reviews'])

# %% [markdown]
# 🗣 Bu göreve başlamadan önce önceden yüklediğiniz `google_translator` paketini kullanarak bu yorumları çevirin:

# %%
# !pip install deep-translator

from deep_translator import GoogleTranslator
translator = GoogleTranslator(source='auto', target='en')

translated_reviews = []

for review in bad_reviews_list:

    translated_text = translator.translate(review)
    translated_reviews.append(translated_text)
# Out:
# Requirement already satisfied: deep-translator in /home/elf/.pyenv/versions/3.12.9/envs/workintech/lib/python3.12/site-packages (1.11.4)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.9.1 in /home/elf/.pyenv/versions/3.12.9/envs/workintech/lib/python3.12/site-packages (from deep-translator) (4.13.3)
# Requirement already satisfied: requests<3.0.0,>=2.23.0 in /home/elf/.pyenv/versions/3.12.9/envs/workintech/lib/python3.12/site-packages (from deep-translator) (2.32.3)
# Requirement already satisfied: soupsieve>1.2 in /home/elf/.pyenv/versions/3.12.9/envs/workintech/lib/python3.12/site-packages (from beautifulsoup4<5.0.0,>=4.9.1->deep-translator) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/elf/.pyenv/versions/3.12.9/envs/workintech/lib/python3.12/site-packages (from beautifulsoup4<5.0.0,>=4.9.1->deep-translator) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/elf/.pyenv/versions/3.12.9/envs/workintech/lib/python3.12/site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/elf/.pyenv/versions/3.12.9/envs/workintech/lib/python3.12/site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/elf/.pyenv/versions/3.12.9/envs/workintech/lib/python3.12/site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/elf/.pyenv/versions/3.12.9/envs/workintech/lib/python3.12/site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2025.1.31)

# %%
for text in translated_reviews[:20]:
    print(text)
# Out:
# I have always bought toner from Kalunga, the first time I ordered from this store, the toner burst in my printer! I want my money back or another product in good condition.
# The same filter as the image I purchased did not come with it.
# I'm waiting for Lannister stores to resolve the problem, I requested to cancel the purchase as the product did not arrive
# In addition to not receiving the product, I had no response about it.
# They didn't deliver on time, it's already been over 30 days, a miserable pair of scissors. I had to buy one here. Because the company didn't commit or send me an email to reassure me.
# I received it and it doesn't work, I requested an exchange or return, let's wait....
# The product only came in the shipping box, packed in a bubble bag, looking like a used product.
# I ordered 3 toners, I didn't receive the 12 A, I received the 36 A (that's ok), of the 3 toners 83A, I only received one, that's terrible!!!!!
# I BOUGHT 4 MODER BOTTLES AND ONLY 1 CAME FOR THE PRICE OF 4.
# UNFAIR IF YOU DON'T GIVE ME SATISFACTION I WILL CANCEL THE PURCHASE ON THE AMERICAN FRAUD CARD
# I haven't received the product yet, I was going to send a message today to find out what happened, despite the delay I always received my products within days, this was the 1st so I still recommend it.
# I'm not satisfied, the deadline was January 2nd and it didn't arrive until today, it's absurd you pay shipping for that
# It arrived late and broke within a week. I contacted the seller for a refund but he did not authorize the return but the repair, he sent me an email giving me a deadline of just 2 days.
# The product has a small defect and I requested an exchange. I'm waiting for instructions.
# I did not receive the product or satisfaction about what happened, I sent five requests about how I could proceed and I did not receive a response. Product has already been paid for and has not arrived. Terrible
# I cannot evaluate a product that has not arrived. In this case, it's the postal service's fault.
# The pillow is a bit deflated and the filling is made up of some loose pieces of foam inside it. It doesn't give the baby firmness.
# I only received the hammock, the hooks were not sent. Please get in touch.
# I didn't receive the product.
# I had problems, I sent an email to return it, Lannister said I would receive a return from Targaryen in 48 hours and it's been 3 days and still nothing.
# A kit with 10 units was ordered and 1 unit was delivered, with 9 pieces missing.

# %% [markdown]
# **Insights** 💡
# - Bazı kötü review’lar delivery ile ilgili (`wait_time`, kaçırılan teslim tarihi, vb.)
# - Ancak bazı kötü review’lar seller veya ürünle ilgili...
#
# Peki iki olası nedeni nasıl ayırt edebiliriz?
#
# Bu Olist’in mutlaka bilmesi gereken bir şey:
# - bazı ürünleri katalogdan mı çıkarmalı?
# - yoksa bazı seller’ları marketplace’ten mi kaldırmalı?
